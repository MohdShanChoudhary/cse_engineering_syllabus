# %% [markdown]
# LAB EST- FINAL PROJECT

# %% [markdown]
# DT PROJECT

# %% [markdown]
# CAR COLLECTIONS

# %%
import pandas as pd
df=pd.read_csv("/content/CARS DATA.csv")
df
# Out:
#             ID  Levy Manufacturer    Model  Prod. year   Category  \
# 0     44020629     -   VOLKSWAGEN     Golf        2012  Hatchback
# 1     45784798     -      HYUNDAI   Sonata        2012      Sedan
# 2     45800257     -       NISSAN    Tiida        2005      Sedan
# 3     45797981   975        VOLVO     XC90        2012       Jeep
# 4     45814303     -         OPEL    Astra        1993  Hatchback
# ...        ...   ...          ...      ...         ...        ...
# 8240  44824410  1357         FIAT    Stilo        2004  Universal
# 8241  45682346     -          BMW  528 F10        2012      Sedan
# 8242  45649860  1646        LEXUS   GX 460        2015       Jeep
# 8243  45809706   784       TOYOTA     Aqua        2017  Hatchback
# 8244  45813163   448        HONDA  Insight        2012  Hatchback
#
#      Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  No    Diesel     2.0 Turbo       0 km          4
# ...

# %%
# Drop some unwanted columns in DATASET

#syntax for drop any Row/Column
#df.drop("Name of row/column", inplace = True, axis = 0 or 1)   0 for row , 1 for column
df.drop("ID", inplace = True , axis=1)

# %%
z=['Levy','Cylinders','Doors']
for i in z:
   df.drop( i,inplace = True , axis = 1)

# %%
df
# Out:
#      Manufacturer    Model  Prod. year   Category Leather interior Fuel type  \
# 0      VOLKSWAGEN     Golf        2012  Hatchback               No    Diesel
# 1         HYUNDAI   Sonata        2012      Sedan              Yes    Petrol
# 2          NISSAN    Tiida        2005      Sedan               No    Petrol
# 3           VOLVO     XC90        2012       Jeep              Yes    Petrol
# 4            OPEL    Astra        1993  Hatchback               No    Petrol
# ...           ...      ...         ...        ...              ...       ...
# 8240         FIAT    Stilo        2004  Universal               No    Petrol
# 8241          BMW  528 F10        2012      Sedan              Yes    Petrol
# 8242        LEXUS   GX 460        2015       Jeep              Yes    Petrol
# 8243       TOYOTA     Aqua        2017  Hatchback              Yes    Petrol
# 8244        HONDA  Insight        2012  Hatchback              Yes    Hybrid
#
# ...

# %%
en=str(input("enter engine type : "))
i=0
d_1=[]
while i<8244:
    if str(df.iloc[i,6])>=en:
        d_1.append(i)
        print(df.iloc[i])
        print("_____________________________________________________________________________________________")
        i+=1
    else:
        i+=1
print(d_1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Drive wheels              Rear
# Wheel               Left wheel
# Color                   Silver
# Airbags                     10
# Price                      NaN
# Name: 7499, dtype: object
# _____________________________________________________________________________________________
# Manufacturer              JEEP
# Model                 Cherokee
# Prod. year                2006
# Category                  Jeep
# Leather interior           Yes
# Fuel type               Diesel
# Engine volume        2.8 Turbo
# Mileage              263318 km
# Gear box type        Automatic
# Drive wheels               4x4
# Wheel               Left wheel
# Color                   Silver
# Airbags                      2
# Price                      NaN
# Name: 7500, dtype: object
# _____________________________________________________________________________________________
# Manufacturer        MERCEDES-BENZ
# Model                       E 240
# ...

# %%
fu=str(input("enter fuel type : "))
d_2=[]
for t in d_1 :
  if str(df.iloc[t,5])==fu:
        d_2.append(t)
        print(df.iloc[t])
        print("_____________________________________________________________________________________________")
# Out:
# Streaming output truncated to the last 5000 lines.
# Gear box type        Tiptronic
# Drive wheels               4x4
# Wheel               Left wheel
# Color                   Silver
# Airbags                      6
# Price                      NaN
# Name: 6705, dtype: object
# _____________________________________________________________________________________________
# Manufacturer              FORD
# Model                 Explorer
# Prod. year                2017
# Category                  Jeep
# Leather interior           Yes
# Fuel type               Petrol
# Engine volume              3.5
# Mileage               52030 km
# Gear box type        Automatic
# Drive wheels             Front
# Wheel               Left wheel
# Color                    White
# Airbags                      4
# Price                      NaN
# Name: 6710, dtype: object
# _____________________________________________________________________________________________
# Manufacturer            TOYOTA
# ...

# %%
dw=str(input("enter drive wheel type : "))
d_3=[]
for t in d_2 :
    if str(df.iloc[t,9])==dw:
        d_3.append(t)
        print(df.iloc[t])
        print("_____________________________________________________________________________________________")
# Out:
# Streaming output truncated to the last 5000 lines.
# Gear box type        Tiptronic
# Drive wheels             Front
# Wheel               Left wheel
# Color                    White
# Airbags                      0
# Price                      NaN
# Name: 4166, dtype: object
# _____________________________________________________________________________________________
# Manufacturer            TOYOTA
# Model                    Camry
# Prod. year                2015
# Category                 Sedan
# Leather interior           Yes
# Fuel type               Petrol
# Engine volume              2.5
# Mileage               80000 km
# Gear box type        Tiptronic
# Drive wheels             Front
# Wheel               Left wheel
# Color                     Blue
# Airbags                     16
# Price                      NaN
# Name: 4178, dtype: object
# _____________________________________________________________________________________________
# Manufacturer         CHEVROLET
# ...

# %%
co=str(input("enter category : "))
d_4=[]
print("\nTHESE are the cars witch fit you most : \n")
for t in d_3 :
    if str(df.iloc[t,3])==co:
        d_4.append(t)
        print(df.iloc[t])
        print("_____________________________________________________________________________________________")
# Out:
# Streaming output truncated to the last 5000 lines.
# Gear box type        Automatic
# Drive wheels             Front
# Wheel               Left wheel
# Color                    White
# Airbags                      8
# Price                      NaN
# Name: 2962, dtype: object
# _____________________________________________________________________________________________
# Manufacturer               KIA
# Model                   Optima
# Prod. year                2016
# Category                 Sedan
# Leather interior            No
# Fuel type               Petrol
# Engine volume              2.4
# Mileage              131200 km
# Gear box type        Tiptronic
# Drive wheels             Front
# Wheel               Left wheel
# Color                     Grey
# Airbags                      8
# Price                      NaN
# Name: 2963, dtype: object
# _____________________________________________________________________________________________
# Manufacturer                CHRYSLER
# ...

# %%
co= input("Gear box type(Automatic/Tiptronic/Manual/Variator)  : ")
d_5=[]
print("\nTHESE are the cars witch fit you most : \n")
for t in d_4 :
    if str(df.iloc[t,8])==co:
        d_5.append(t)
        print(df.iloc[t])
        print("_____________________________________________________________________________________________")

print(d_5)
# Out:
# Gear box type(Automatic/Tiptronic/Manual/Variator)  : Automatic
#
# THESE are the cars witch fit you most :
#
# Manufacturer            TOYOTA
# Model                    Camry
# Prod. year                2010
# Category                 Sedan
# Leather interior           Yes
# Fuel type               Petrol
# Engine volume              2.5
# Mileage               74160 km
# Gear box type        Automatic
# Drive wheels             Front
# Wheel               Left wheel
# Color                     Blue
# Airbags                     12
# Price                      NaN
# Name: 125, dtype: object
# _____________________________________________________________________________________________
# Manufacturer            TOYOTA
# Model                    Camry
# Prod. year                2013
# Category                 Sedan
# Leather interior            No
# Fuel type               Petrol
# Engine volume              2.5
# Mileage              136448 km
# Gear box type        Automatic
# ...
